# %%
from bs4 import BeautifulSoup
from lxml import etree
import requests
import colorama
from colorama import Fore
from datetime import datetime
import pandas as pd , numpy as np 

import warnings
warnings.filterwarnings("ignore")

# %autosave 1
# Out:
# Autosaving every 1 seconds

# %%
# creating the list of dates 
list_of_dates = []

try:
    #taking input from user
    start_date = input("Enter start date (in YYYY MM DD) : " )
    end_date = input("Enter end date (in YYYY MM DD) : " )
#     end_date = '2022 4 16'
#     start_date = '2022 3 25'

    #adding up condition 
    if start_date > end_date :
        print(Fore.RED+ '\nstart date must come before end date')

    #appending to the list includes both dates
    else:
        for d in pd.date_range(start_date, end_date,inclusive="both"):
            list_of_dates.append(d.strftime("%#d %b %Y"))

#dealing with error/s    
except ValueError:
    print(Fore.RED +"\nAdd the dates in correct format (in YYYY MM DD)")
# Out:
# Enter start date (in YYYY MM DD) : 2022 1 1
# Enter end date (in YYYY MM DD) : 2022 4 16

# %%
#deciding how many pages to scrape
if len(list_of_dates) <= 6:
    factor = len(list_of_dates)
else:
    factor = len(list_of_dates)/6

print(f"scrapping {int(factor)} pages")
# Out:
# scrapping 17 pages

# %%
# %%time
#there are 142 pages

titles = []
dates = []
links = []

try:
    
    for page_number in range(int(factor)):
#     for page_number in range(3):
        #getting the urls
        url =  f'https://www.nokia.com/about-us/newsroom/press-and-stock-exchange-releases/?page={page_number}/'

        #parsing
        source = requests.get(url)
        soup = BeautifulSoup(source.content,'lxml')

        try:
            #creating container and fetching the data
            all_containers = soup.findAll('div', {'class' :'views-row'})
            for container in all_containers:
                published_date = container.find('label').text
                
                if published_date in list_of_dates:
                    link = container.find('a')['href']
                    title = container.find('h3').text
                    dates.append(published_date)
                    titles.append(title)
                    links.append("https://www.nokia.com" + link)

            print(f"scrapping done for page {page_number}\n")
            
        except:
            pass
except:
    pass
# Out:
# scrapping done for page 0
#
# scrapping done for page 1
#
# scrapping done for page 2
#
# scrapping done for page 3
#
# scrapping done for page 4
#
# scrapping done for page 5
#
# scrapping done for page 6
#
# scrapping done for page 7
#
# scrapping done for page 8
#
# scrapping done for page 9
#
# scrapping done for page 10
#
# scrapping done for page 11
#
# scrapping done for page 12
#
# scrapping done for page 13
#
# scrapping done for page 14
#
# scrapping done for page 15
#
# scrapping done for page 16
#
# CPU times: total: 1.06 s
# Wall time: 4.4 s

# %%
#zippling the list so that it'll form the tuple
zipped = list(zip(dates,titles,links))
zipped[:3]
# Out:
# [('14 Apr 2022',
#   'Nokia Corporation: Repurchase of own shares on 14.04.2022\n',
#   'https://www.nokia.com/about-us/news/releases/2022/04/14/nokia-corporation-repurchase-of-own-shares-on-14042022/'),
#  ('13 Apr 2022',
#   'Nokia Corporation: Repurchase of own shares on 13.04.2022\n',
#   'https://www.nokia.com/about-us/news/releases/2022/04/13/nokia-corporation-repurchase-of-own-shares-on-13042022/'),
#  ('13 Apr 2022',
#   'Nokia demonstrates live D-Band microwave backhaul connection\n',
#   'https://www.nokia.com/about-us/news/releases/2022/04/13/nokia-demonstrates-live-d-band-microwave-backhaul-connection/')]

# %%
#creating the csv 
temp_csv = pd.DataFrame(zipped,columns=['date','title','link'])
temp_csv
# Out:
#             date                                              title  \
# 0    14 Apr 2022  Nokia Corporation: Repurchase of own shares on...
# 1    13 Apr 2022  Nokia Corporation: Repurchase of own shares on...
# 2    13 Apr 2022  Nokia demonstrates live D-Band microwave backh...
# 3    12 Apr 2022  Nokia Corporation: Repurchase of own shares on...
# 4    12 Apr 2022  Nokia to exit the Russian market, no impact to...
# ..           ...                                                ...
# 111  12 Jan 2022  Nokia joins RE100 as part of target to move to...
# 112  12 Jan 2022  Nokia and Schweizer Electronics deploy AI-base...
# 113  11 Jan 2022  Nokia expects to exceed 2021 financial guidanc...
# 114  10 Jan 2022  Nokia selected by Capital Online to upgrade it...
# 115   4 Jan 2022  Nokia and Tele2 expand 5G partnership in the B...
#
#                                                   link
# 0    https://www.nokia.com/about-us/news/releases/2...
# 1    https://www.nokia.com/about-us/news/releases/2...
# 2    https://www.nokia.com/about-us/news/releases/2...
# 3    https://www.nokia.com/about-us/news/releases/2...
# 4    https://www.nokia.com/about-us/news/releases/2...
# ..                                                 ...
# 111  https://www.nokia.com/about-us/news/releases/2...
# 112  https://www.nokia.com/about-us/news/releases/2...
# 113  https://www.nokia.com/about-us/news/releases/2...
# 114  https://www.nokia.com/about-us/news/releases/2...
# 115  https://www.nokia.com/about-us/news/releases/2...
#
# [116 rows x 3 columns]

# %%
# %%time
articles = []

for link_number in range(len(temp_csv)):
    
    #getting the url from data
    url = temp_csv['link'][link_number]
    
    #parsing
    source = requests.get(url)
    soup = BeautifulSoup(source.content,'lxml')
     
    try:    
        #creating container and fetching the data    
        all_containers = soup.findAll('div',{'class' :"main-content-region"})

        for container in all_containers:
            article = container.text
            articles.append(article)

        print(f"scrapping done for url {link_number}\n")
        
    except:
        pass
# Out:
# scrapping done for url 0
#
# scrapping done for url 1
#
# scrapping done for url 2
#
# scrapping done for url 3
#
# scrapping done for url 4
#
# scrapping done for url 5
#
# scrapping done for url 6
#
# scrapping done for url 7
#
# scrapping done for url 8
#
# scrapping done for url 9
#
# scrapping done for url 10
#
# scrapping done for url 11
#
# scrapping done for url 12
#
# scrapping done for url 13
#
# scrapping done for url 14
#
# scrapping done for url 15
#
# scrapping done for url 16
#
# scrapping done for url 17
#
# scrapping done for url 18
#
# scrapping done for url 19
#
# scrapping done for url 20
#
# scrapping done for url 21
#
# scrapping done for url 22
#
# scrapping done for url 23
#
# scrapping done for url 24
#
# scrapping done for url 25
#
# scrapping done for url 26
#
# scrapping done for url 27
#
# scrapping done for url 28
#
# scrapping done for url 29
#
# scrapping done for url 30
#
# scrapping done for url 31
#
# scrapping done for url 32
#
# scrapping done for url 33
#
# scrapping done for url 34
#
# scrapping done for url 35
#
# scrapping done for url 36
#
# scrapping done for url 37
#
# scrapping done for url 38
#
# scrapping done for url 39
#
# scrapping done for url 40
#
# scrapping done for url 41
#
# scrapping done for url 42
#
# scrapping done for url 43
#
# scrapping done for url 44
#
# scrapping done for url 45
#
# scrapping done for url 46
#
# scrapping done for url 47
#
# scrapping done for url 48
#
# scrapping done for url 49
#
# scrapping done for url 50
#
# scrapping done for url 51
#
# scrapping done for url 52
#
# scrapping done for url 53
#
# scrapping done for url 54
#
# scrapping done for url 55
#
# scrapping done for url 56
#
# scrapping done for url 57
#
# scrapping done for url 58
#
# scrapping done for url 59
#
# scrapping done for url 60
#
# scrapping done for url 61
#
# scrapping done for url 62
#
# scrapping done for url 63
#
# scrapping done for url 64
#
# scrapping done for url 65
#
# scrapping done for url 66
#
# scrapping done for url 67
#
# scrapping done for url 68
#
# scrapping done for url 69
#
# scrapping done for url 70
#
# scrapping done for url 71
#
# scrapping done for url 72
#
# scrapping done for url 73
#
# scrapping done for url 74
#
# scrapping done for url 75
#
# scrapping done for url 76
#
# scrapping done for url 77
#
# scrapping done for url 78
#
# scrapping done for url 79
#
# scrapping done for url 80
#
# scrapping done for url 81
#
# scrapping done for url 82
#
# scrapping done for url 83
#
# scrapping done for url 84
#
# scrapping done for url 85
#
# scrapping done for url 86
#
# scrapping done for url 87
#
# scrapping done for url 88
#
# scrapping done for url 89
#
# scrapping done for url 90
#
# scrapping done for url 91
#
# scrapping done for url 92
#
# scrapping done for url 93
#
# scrapping done for url 94
#
# scrapping done for url 95
#
# scrapping done for url 96
#
# scrapping done for url 97
#
# scrapping done for url 98
#
# scrapping done for url 99
#
# scrapping done for url 100
#
# scrapping done for url 101
#
# scrapping done for url 102
#
# scrapping done for url 103
#
# scrapping done for url 104
#
# scrapping done for url 105
#
# scrapping done for url 106
#
# scrapping done for url 107
#
# scrapping done for url 108
#
# scrapping done for url 109
#
# scrapping done for url 110
#
# scrapping done for url 111
#
# scrapping done for url 112
#
# scrapping done for url 113
#
# scrapping done for url 114
#
# scrapping done for url 115
#
# CPU times: total: 6.64 s
# Wall time: 27.7 s

# %%
temp_csv['article'] = articles
temp_csv
# Out:
#             date                                              title  \
# 0    14 Apr 2022  Nokia Corporation: Repurchase of own shares on...
# 1    13 Apr 2022  Nokia Corporation: Repurchase of own shares on...
# 2    13 Apr 2022  Nokia demonstrates live D-Band microwave backh...
# 3    12 Apr 2022  Nokia Corporation: Repurchase of own shares on...
# 4    12 Apr 2022  Nokia to exit the Russian market, no impact to...
# ..           ...                                                ...
# 111  12 Jan 2022  Nokia joins RE100 as part of target to move to...
# 112  12 Jan 2022  Nokia and Schweizer Electronics deploy AI-base...
# 113  11 Jan 2022  Nokia expects to exceed 2021 financial guidanc...
# 114  10 Jan 2022  Nokia selected by Capital Online to upgrade it...
# 115   4 Jan 2022  Nokia and Tele2 expand 5G partnership in the B...
#
#                                                   link  \
# 0    https://www.nokia.com/about-us/news/releases/2...
# 1    https://www.nokia.com/about-us/news/releases/2...
# 2    https://www.nokia.com/about-us/news/releases/2...
# 3    https://www.nokia.com/about-us/news/releases/2...
# 4    https://www.nokia.com/about-us/news/releases/2...
# ..                                                 ...
# 111  https://www.nokia.com/about-us/news/releases/2...
# 112  https://www.nokia.com/about-us/news/releases/2...
# 113  https://www.nokia.com/about-us/news/releases/2...
# 114  https://www.nokia.com/about-us/news/releases/2...
# 115  https://www.nokia.com/about-us/news/releases/2...
#
#                                                article
# 0    \nNokia CorporationStock Exchange Release14 Ap...
# 1    \nNokia CorporationStock Exchange Release13 Ap...
# 2    \nPress Release\nNokia demonstrates live D-Ban...
# 3    \nNokia CorporationStock Exchange Release12 Ap...
# 4    \nNokia CorporationStock Exchange Release12 Ap...
# ..                                                 ...
# 111  \nPress Release\nNokia joins RE100 as part of ...
# 112  \nPress Release\nNokia and Schweizer Electroni...
# 113  \nNokia Corporation Inside information11 Janua...
# 114  \nPress Release\nNokia selected by Capital Onl...
# 115  \nPress Release\nNokia and Tele2 expand 5G par...
#
# [116 rows x 4 columns]

# %%
#to csv
temp_csv.to_csv('bs4 generated nokia.csv')

#to json
temp_csv.to_json('bs4 generated nokia.json')
